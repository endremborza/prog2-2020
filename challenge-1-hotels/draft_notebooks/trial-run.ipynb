# %% [markdown]
# # Evaluate and compare solutions here

# %%
from jkg_evaluators.challenges.data.hotels import HotelSolutionComparator

# %%
levels = [
    {"data_sizes": [10000],
     "input_sizes": [1, 2, 5, 10]},
    {"data_sizes": [10000, 50000, 100000, 200000],
     "input_sizes": [5]},
    {"data_sizes": [50000],
     "input_sizes": [1, 10, 100, 1000]},
    {"data_sizes": [500000],
     "input_sizes": [1, 10, 100, 1000]}
]

# %%
sc = HotelSolutionComparator(solutions_to_compare=["k_nearest_preload_v5", "k_nearest_v4"], **levels[3]) #all can be changed to list of solutions

# %%
sc.run_comparison()
# Out:
# solution: k_nearest_preload_v5
# running setup-env-command for k_nearest_preload_v5
# running etl-command for k_nearest_preload_v5
# input size: 1 - data size: 500000
# running process-command for k_nearest_preload_v5
# input size: 10 - data size: 500000
# running process-command for k_nearest_preload_v5
# input size: 100 - data size: 500000
# running process-command for k_nearest_preload_v5
# input size: 1000 - data size: 500000
# running process-command for k_nearest_preload_v5
# no cleanup-command for k_nearest_preload_v5
# solution: k_nearest_v4
# running setup-env-command for k_nearest_v4
# running etl-command for k_nearest_v4
# input size: 1 - data size: 500000
# running process-command for k_nearest_v4
# input size: 10 - data size: 500000
# running process-command for k_nearest_v4
# input size: 100 - data size: 500000
# running process-command for k_nearest_v4
# input size: 1000 - data size: 500000
# running process-command for k_nearest_v4
# no cleanup-command for k_nearest_v4

# %%
sc.plot_comparison()

# %%
sc.output_comparison()
# Out:
#                                                         lat  \
# solution                                      itertuples_v3
# level_1 name
# 0       Hôtel Coco beach                           6.151320
# 1       Campement Tako Mayo                       12.365223
# 2       Kunene River Lodge                       -17.354590
# 3       Ca' Amanda                                16.597040
# 4       ibis Abidjan Marcory                       5.290072
# 5       Pensionato Dona Rosa                      -7.238313
# 6       Hilton Seychelles Labriz Resort & Spa     -4.478129
# 7       Hotel do Forte                             0.027211
# 8       Jacaranda Beach Resort                    -3.350673
# 9       Landmark Hotel Matema Beach               -9.487408
# 10      Wise Owl Motel                           -18.951930
# 11      Stay Plus Extended Stay Suites            32.398128
# 12      T'Niqua Stable Inn                       -34.094399
# 13      Mantis St Helena                         -15.925860
# 14      Hostel a Coroa                           -22.977270
# 15      Greenways Beach House                    -34.137570
# 16      Hôtel Chicoutimi                          48.428619
# 17      Hotel Awalé Plage - Village vacances       6.269350
# 18      Happy Home                                55.441989
# 19      Dzibanana Lodge & Camping                -19.864969
#
#                                                                     \
# solution                                      k_nearest_preload_v5
# level_1 name
# 0       Hôtel Coco beach                                  6.151320
# 1       Campement Tako Mayo                              12.365223
# 2       Kunene River Lodge                              -17.354590
# 3       Ca' Amanda                                       16.597040
# 4       ibis Abidjan Marcory                              5.290072
# 5       Pensionato Dona Rosa                             -7.238313
# 6       Hilton Seychelles Labriz Resort & Spa            -4.478129
# 7       Hotel do Forte                                    0.027211
# 8       Jacaranda Beach Resort                           -3.350673
# 9       Landmark Hotel Matema Beach                      -9.487408
# 10      Wise Owl Motel                                  -18.951930
# 11      Stay Plus Extended Stay Suites                   32.398128
# 12      T'Niqua Stable Inn                              -34.094399
# 13      Mantis St Helena                                -15.925860
# 14      Hostel a Coroa                                  -22.977270
# 15      Greenways Beach House                           -34.137570
# 16      Hôtel Chicoutimi                                 48.428619
# 17      Hotel Awalé Plage - Village vacances              6.269350
# 18      Happy Home                                       55.441989
# 19      Dzibanana Lodge & Camping                       -19.864969
#
#                                                         lon  \
# solution                                      itertuples_v3
# level_1 name
# 0       Hôtel Coco beach                           1.300570
# 1       Campement Tako Mayo                      -12.312269
# 2       Kunene River Lodge                        13.880972
# 3       Ca' Amanda                               -22.900014
# 4       ibis Abidjan Marcory                      -3.972996
# 5       Pensionato Dona Rosa                     -39.416795
# 6       Hilton Seychelles Labriz Resort & Spa     55.247224
# 7       Hotel do Forte                           -51.052704
# 8       Jacaranda Beach Resort                    40.018601
# 9       Landmark Hotel Matema Beach               34.023836
# 10      Wise Owl Motel                            32.649635
# 11      Stay Plus Extended Stay Suites           -81.756592
# 12      T'Niqua Stable Inn                        23.314454
# 13      Mantis St Helena                          -5.717330
# 14      Hostel a Coroa                           -42.025130
# 15      Greenways Beach House                     18.333140
# 16      Hôtel Chicoutimi                         -71.053878
# 17      Hotel Awalé Plage - Village vacances       1.787140
# 18      Happy Home                                65.326185
# 19      Dzibanana Lodge & Camping                 26.493126
#
#
# solution                                      k_nearest_preload_v5
# level_1 name
# 0       Hôtel Coco beach                                  1.300570
# 1       Campement Tako Mayo                             -12.312269
# 2       Kunene River Lodge                               13.880972
# 3       Ca' Amanda                                      -22.900014
# 4       ibis Abidjan Marcory                             -3.972996
# 5       Pensionato Dona Rosa                            -39.416795
# 6       Hilton Seychelles Labriz Resort & Spa            55.247224
# 7       Hotel do Forte                                  -51.052704
# 8       Jacaranda Beach Resort                           40.018601
# 9       Landmark Hotel Matema Beach                      34.023836
# 10      Wise Owl Motel                                   32.649635
# 11      Stay Plus Extended Stay Suites                  -81.756592
# 12      T'Niqua Stable Inn                               23.314454
# 13      Mantis St Helena                                 -5.717330
# 14      Hostel a Coroa                                  -42.025130
# 15      Greenways Beach House                            18.333140
# 16      Hôtel Chicoutimi                                -71.053878
# 17      Hotel Awalé Plage - Village vacances              1.787140
# 18      Happy Home                                       65.326185
# 19      Dzibanana Lodge & Camping                        26.493126
