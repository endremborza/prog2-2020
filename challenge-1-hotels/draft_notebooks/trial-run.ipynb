# %% [markdown]
# # Evaluate and compare solutions here

# %%
from jkg_evaluators.challenges.data.hotels import HotelSolutionComparator

# %%
levels = [
    {"data_sizes": [10000],
     "input_sizes": [1, 2, 5, 10]},
    {"data_sizes": [10000, 50000, 100000, 200000],
     "input_sizes": [5]},
    {"data_sizes": [50000],
     "input_sizes": [1, 10, 100, 1000]},
    {"data_sizes": [500000],
     "input_sizes": [1, 10, 100, 1000]}
]

# %%
sc = HotelSolutionComparator(solutions_to_compare=["TreeV3_solution", "TreeV2_solution"], **levels[3])

# %%
sc.run_comparison()
# Out:
# solution: TreeV3_solution
# running setup-env-command for TreeV3_solution
# running etl-command for TreeV3_solution
# input size: 1 - data size: 500000
# running process-command for TreeV3_solution
# input size: 10 - data size: 500000
# running process-command for TreeV3_solution
# input size: 100 - data size: 500000
# running process-command for TreeV3_solution
# input size: 1000 - data size: 500000
# running process-command for TreeV3_solution
# no cleanup-command for TreeV3_solution
# solution: TreeV2_solution
# running setup-env-command for TreeV2_solution
# running etl-command for TreeV2_solution
# input size: 1 - data size: 500000
# running process-command for TreeV2_solution
# input size: 10 - data size: 500000
# running process-command for TreeV2_solution
# input size: 100 - data size: 500000
# running process-command for TreeV2_solution
# input size: 1000 - data size: 500000
# running process-command for TreeV2_solution
# no cleanup-command for TreeV2_solution

# %%
sc.plot_comparison()

# %%
sc.output_comparison()
# Out:
#                                               lat             lon
# solution                          TreeV3_solution TreeV3_solution
# level_1 name
# 0       Drake Inn                       -0.956210      -90.970729
# 1       Residence Foulsafat            -19.670325       63.447054
# 2       Richards Travel Lodge          -15.928634       -5.715175
# 3       Cozy View Apartment             13.119728      -59.444460
# 4       Bakwa Lodge                    -19.739080       63.470700
# ...                                           ...             ...
# 1106    Hotel Miranda & Miranda         17.200483      -25.092562
# 1107    Seti Abu Simbel Hotel           22.338250       31.614220
# 1108    Carilafquen Turismo y Spa      -33.107570      -71.690080
# 1109    Augusta Sheoak Chalets         -34.314470      115.126809
# 1110    Ubumwe Hotel Gisenyi            -1.695810       29.247014
#
# [1111 rows x 2 columns]

# %%
# %%time
import sys
sys.path.append('/Users/benceszabo/OneDrive/SzBence/Rajk/Prog_2/prog2-2020/challenge-1-hotels/solutions/TreeV3_solution')
import ETL
# Out:
# CPU times: user 21 µs, sys: 13 µs, total: 34 µs
# Wall time: 22.9 µs

# %%
# %%time
df = ETL.df
bt = ETL.bt
# Out:
# CPU times: user 5 µs, sys: 0 ns, total: 5 µs
# Wall time: 8.82 µs
