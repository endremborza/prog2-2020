# %% [markdown]
# # Evaluate and compare solutions here

# %%
from jkg_evaluators.challenges.data.hotels import HotelSolutionComparator

# %%
levels = [
    {"data_sizes": [10000],
     "input_sizes": [1, 2, 5, 10]},
    {"data_sizes": [10000, 50000, 100000, 200000],
     "input_sizes": [5]},
    {"data_sizes": [50000],
     "input_sizes": [1, 10, 100, 1000]},
    {"data_sizes": [500000],
     "input_sizes": [1, 10, 100, 1000]}
]

# %%
sc = HotelSolutionComparator(solutions_to_compare=["base_solution", "k_nearest_v4"], **levels[0]) #all can be changed to list of solutions

# %%
sc.run_comparison()
# Out:
# solution: base_solution
# running setup-env-command for base_solution
# running etl-command for base_solution
# input size: 1 - data size: 10000
# running process-command for base_solution
# input size: 2 - data size: 10000
# running process-command for base_solution
# input size: 5 - data size: 10000
# running process-command for base_solution
# input size: 10 - data size: 10000
# running process-command for base_solution
# no cleanup-command for base_solution
# solution: k_nearest_v4
# running setup-env-command for k_nearest_v4
# running etl-command for k_nearest_v4
# input size: 1 - data size: 10000
# running process-command for k_nearest_v4
# input size: 2 - data size: 10000
# running process-command for k_nearest_v4
# input size: 5 - data size: 10000
# running process-command for k_nearest_v4
# input size: 10 - data size: 10000
# running process-command for k_nearest_v4
# no cleanup-command for k_nearest_v4

# %%
sc.plot_comparison()

# %%
sc.output_comparison()
# Out:
#                                               lat                        lon  \
# solution                            base_solution k_nearest_v4 base_solution
# level_1 name
# 0       Angel Eyes House                25.696476    25.696476     32.629078
# 1       Le Koral Beach Hotel  LeKBH      5.196061     5.196061     -3.739284
# 2       Menzeh Fes                      34.041673    34.041673     -4.994623
# 3       Santa Cruz Village Hotel        32.689078    32.689078    -16.793521
# 4       Downtown Iquitos House          -3.750880    -3.750880    -73.247510
# 5       Agbo Hotel                       8.005962     8.005962     80.923960
# 6       Mayfair Hotel                  -31.599143   -31.599143     28.781877
# 7       Out of Africa Guest House      -20.472554   -20.472554     16.653728
# 8       Pousada Guedes Noronha          -3.844700    -3.844700    -32.407090
# 9       Campement Tako Mayo             12.365223    12.365223    -12.312269
# 10      Fulidhoo Laperla Guesthouse      3.680560     3.680560     73.416042
# 11      Knights Inn Lethbridge          49.684477    49.684477   -112.805532
# 12      Fawlty Towers                  -17.854170   -17.854170     25.855191
# 13      Da Vinci Gorilla Lodge          -1.430346    -1.430346     29.561256
# 14      Jag Boutique Hotel              47.558233    47.558233    -52.712704
# 15      King Fisher Village             15.274973    15.274973    -23.757431
# 16      Yaas Hotel Dakar Almadies       14.742797    14.742797    -17.520177
# 17      Melbourne Inn                   13.065819    13.065819    -59.565230
#
#
# solution                            k_nearest_v4
# level_1 name
# 0       Angel Eyes House               32.629078
# 1       Le Koral Beach Hotel  LeKBH    -3.739284
# 2       Menzeh Fes                     -4.994623
# 3       Santa Cruz Village Hotel      -16.793521
# 4       Downtown Iquitos House        -73.247510
# 5       Agbo Hotel                     80.923960
# 6       Mayfair Hotel                  28.781877
# 7       Out of Africa Guest House      16.653728
# 8       Pousada Guedes Noronha        -32.407090
# 9       Campement Tako Mayo           -12.312269
# 10      Fulidhoo Laperla Guesthouse    73.416042
# 11      Knights Inn Lethbridge       -112.805532
# 12      Fawlty Towers                  25.855191
# 13      Da Vinci Gorilla Lodge         29.561256
# 14      Jag Boutique Hotel            -52.712704
# 15      King Fisher Village           -23.757431
# 16      Yaas Hotel Dakar Almadies     -17.520177
# 17      Melbourne Inn                 -59.565230
