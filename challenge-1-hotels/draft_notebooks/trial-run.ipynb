# %% [markdown]
# # Evaluate and compare solutions here

# %%
from jkg_evaluators.challenges.data.hotels import HotelSolutionComparator

# %%
levels = [
    {"data_sizes": [10000],
     "input_sizes": [1, 2, 5, 10]},
    {"data_sizes": [10000, 50000, 100000, 200000],
     "input_sizes": [5]},
    {"data_sizes": [50000],
     "input_sizes": [1, 10, 100, 1000]},
    {"data_sizes": [500000],
     "input_sizes": [1, 10, 100, 1000]}
]

# %%
sc = HotelSolutionComparator(solutions_to_compare=["Tree_solution"], **levels[3])

# %%
sc.run_comparison()
# Out:
# solution: Tree_solution
# running setup-env-command for Tree_solution
# running etl-command for Tree_solution
# input size: 1 - data size: 500000
# running process-command for Tree_solution
# input size: 10 - data size: 500000
# running process-command for Tree_solution
# input size: 100 - data size: 500000
# running process-command for Tree_solution
# input size: 1000 - data size: 500000
# running process-command for Tree_solution
# no cleanup-command for Tree_solution

# %%
sc.plot_comparison()

# %%
sc.output_comparison()
# Out:
#                                                 lat           lon
# solution                              Tree_solution Tree_solution
# level_1 name
# 0       Grand Ngwe Saung Resort           16.868706     94.381547
# 1       Pension Tamatuamai               -14.965840   -147.631560
# 2       Eskaleh Nubian House              22.346496     31.618418
# 3       Radisson Blu Hotel, N Djamena     12.088592     15.071272
# 4       Aldeia da Cuada                   39.440480    -31.255790
# ...                                             ...           ...
# 1106    iu Hotel Namibe                  -15.193210     12.148950
# 1107    Kangle Plaza Hotel                 5.970164     10.174528
# 1108    OYO Pousada Bem Estar            -22.041023    -41.046709
# 1109    Nikki Hotel                       13.529476      2.093523
# 1110    Auberge Boulaos                   11.573180     43.155895
#
# [1111 rows x 2 columns]
