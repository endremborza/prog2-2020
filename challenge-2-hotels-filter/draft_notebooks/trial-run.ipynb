# %% [markdown]
# # Evaluate and compare solutions here

# %%
# !pip install --upgrade /home/borza/pcloud/knowledge/my_packages/jkg_evaluators/
# Out:
# Invalid requirement: '/home/borza/pcloud/knowledge/my_packages/jkg_evaluators/'
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\pip\_vendor\packaging\requirements.py", line 93, in __init__
#     req = REQUIREMENT.parseString(requirement_string)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\pip\_vendor\pyparsing.py", line 1654, in parseString
#     raise exc
#   File "C:\ProgramData\Miniconda3\lib\site-packages\pip\_vendor\pyparsing.py", line 1644, in parseString
#     loc, tokens = self._parse( instring, 0 )
#   File "C:\ProgramData\Miniconda3\lib\site-packages\pip\_vendor\pyparsing.py", line 1402, in _parseNoCache
#     loc,tokens = self.parseImpl( instring, preloc, doActions )
#   File "C:\ProgramData\Miniconda3\lib\site-packages\pip\_vendor\pyparsing.py", line 3417, in parseImpl
#     loc, exprtokens = e._parse( instring, loc, doActions )
#   File "C:\ProgramData\Miniconda3\lib\site-packages\pip\_vendor\pyparsing.py", line 1402, in _parseNoCache
#     loc,tokens = self.parseImpl( instring, preloc, doActions )
#   File "C:\ProgramData\Miniconda3\lib\site-packages\pip\_vendor\pyparsing.py", line 3739, in parseImpl
#     return self.expr._parse( instring, loc, doActions, callPreParse=False )
#   File "C:\ProgramData\Miniconda3\lib\site-packages\pip\_vendor\pyparsing.py", line 1402, in _parseNoCache
#     loc,tokens = self.parseImpl( instring, preloc, doActions )
#   File "C:\ProgramData\Miniconda3\lib\site-packages\pip\_vendor\pyparsing.py", line 3400, in parseImpl
#     loc, resultlist = self.exprs[0]._parse( instring, loc, doActions, callPreParse=False )
#   File "C:\ProgramData\Miniconda3\lib\site-packages\pip\_vendor\pyparsing.py", line 1406, in _parseNoCache
#     loc,tokens = self.parseImpl( instring, preloc, doActions )
#   File "C:\ProgramData\Miniconda3\lib\site-packages\pip\_vendor\pyparsing.py", line 2711, in parseImpl
#     raise ParseException(instring, loc, self.errmsg, self)
# pip._vendor.pyparsing.ParseException: Expected W:(abcd...) (at char 0), (line:1, col:1)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\pip\_internal\req\constructors.py", line 253, in install_req_from_line
#     req = Requirement(req)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\pip\_vendor\packaging\requirements.py", line 96, in __init__
#     requirement_string[e.loc:e.loc + 8], e.msg
# pip._vendor.packaging.requirements.InvalidRequirement: Parse error at "'/home/bo'": Expected W:(abcd...)

# %%
from jkg_evaluators.challenges.data.hotels import HotelFilterSolutionComparator

# %%
levels = [
    {"data_sizes": [10000],
     "input_sizes": [1, 2, 5, 10]},
    {"data_sizes": [10000, 50000, 100000, 200000],
     "input_sizes": [5]},
    {"data_sizes": [50000],
     "input_sizes": [1, 10, 100, 1000]},
    {"data_sizes": [500000],
     "input_sizes": [1, 10, 100, 1000]}
]

# %%
sc = HotelFilterSolutionComparator(
    solutions_to_compare=[
        "better_solution_v2"
    ], 
    **levels[0])

# %%
sc.run_comparison()
# Out:
# solution: better_solution_v2
# running setup-env-command for better_solution_v2
#
#
# better_solution_v2 setup-env-command ERROR:
# --
#   Failed building wheel for pykdtree
# Command "C:\ProgramData\Miniconda3\python.exe -u -c "import setuptools, tokenize;__file__='C:\\Users\\asus\\AppData\\Local\\Temp\\pip-install-i0u2gniv\\pykdtree\\setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" install --record C:\Users\asus\AppData\Local\Temp\pip-record-xehq0pq7\install-record.txt --single-version-externally-managed --compile" failed with error code 1 in C:\Users\asus\AppData\Local\Temp\pip-install-i0u2gniv\pykdtree\
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-4-5dd3aa4704f3> in <module>
# ----> 1 sc.run_comparison()
#
# c:\programdata\miniconda3\lib\site-packages\jkg_evaluators\challenges\data\comparator_class.py in run_comparison(self)
#      88
#      89             self._try_running_command(
# ---> 90                 commands, "setup-env-command", act_solution
#      91             )
#      92
#
# c:\programdata\miniconda3\lib\site-packages\jkg_evaluators\challenges\data\comparator_class.py in _try_running_command(self, command_dic, command_name, act_solution)
#      62                 print(f"\n\n{act_solution} {command_name} ERROR:\n--")
#      63                 print(_stderr.decode("utf-8"))
# ---> 64                 raise RuntimeError(_stderr.decode("utf-8"))
#      65
#      66         else:
#
# RuntimeError:   Failed building wheel for pykdtree
# Command "C:\ProgramData\Miniconda3\python.exe -u -c "import setuptools, tokenize;__file__='C:\\Users\\asus\\AppData\\Local\\Temp\\pip-install-i0u2gniv\\pykdtree\\setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" install --record C:\Users\asus\AppData\Local\Temp\pip-record-xehq0pq7\install-record.txt --single-version-externally-managed --compile" failed with error code 1 in C:\Users\asus\AppData\Local\Temp\pip-install-i0u2gniv\pykdtree\

# %%
sc.plot_comparison()

# %%
sc.output_comparison()
# Out:
#                                                                    current-price  \
# solution                                                           base_solution
# level_1 missing name
# 0       True    0                                                            0.0
# 1       0       The Quilon Beach Hotel and Convention Center                 0.0
# 2       True    0                                                            0.0
# 3       0       Hotel Rey David                                              0.0
# 4       0       Elsje's Country Inn                                          0.0
# 5       0       21 Palms                                                     0.0
# 6       0       Hostel Mendoza Suites                                        0.0
# 7       0       Royal Chalet Guest House                                     0.0
# 8       0       Travelodge by Wyndham New Orleans West Harvey H...           0.0
# 9       0       Grand Hotel Açores Atlântico                                 0.0
# 10      0       Gino Feruci Braga                                            0.0
# 11      0       Aloft Montevideo Hotel                                       0.0
# 12      True    0                                                            0.0
# 13      0       Tapis Rouge VIP Boutique Batumi                              0.0
# 14      0       Refugi Cap del Rec                                           0.0
# 15      0       Extended Stay America Philadelphia Mt Laurel - ...           0.0
# 16      0       Nut Grove Manor                                              0.0
# 17      0       The Station Room                                             0.0
#
#                                                                                     \
# solution                                                           better_solution
# level_1 missing name
# 0       True    0                                                              0.0
# 1       0       The Quilon Beach Hotel and Convention Center                  51.0
# 2       True    0                                                              0.0
# 3       0       Hotel Rey David                                               16.0
# 4       0       Elsje's Country Inn                                           58.0
# 5       0       21 Palms                                                      65.0
# 6       0       Hostel Mendoza Suites                                         22.0
# 7       0       Royal Chalet Guest House                                      98.0
# 8       0       Travelodge by Wyndham New Orleans West Harvey H...            70.0
# 9       0       Grand Hotel Açores Atlântico                                  86.0
# 10      0       Gino Feruci Braga                                             32.0
# 11      0       Aloft Montevideo Hotel                                        84.0
# 12      True    0                                                              0.0
# 13      0       Tapis Rouge VIP Boutique Batumi                               59.0
# 14      0       Refugi Cap del Rec                                            65.0
# 15      0       Extended Stay America Philadelphia Mt Laurel - ...            92.0
# 16      0       Nut Grove Manor                                              135.0
# 17      0       The Station Room                                             115.0
#
#                                                                              lat  \
# solution                                                           base_solution
# level_1 missing name
# 0       True    0                                                       0.000000
# 1       0       The Quilon Beach Hotel and Convention Center            8.875560
# 2       True    0                                                       0.000000
# 3       0       Hotel Rey David                                        16.789122
# 4       0       Elsje's Country Inn                                   -26.088950
# 5       0       21 Palms                                               19.295280
# 6       0       Hostel Mendoza Suites                                 -32.885292
# 7       0       Royal Chalet Guest House                               31.473880
# 8       0       Travelodge by Wyndham New Orleans West Harvey H...     29.899901
# 9       0       Grand Hotel Açores Atlântico                           37.740209
# 10      0       Gino Feruci Braga                                      -6.917909
# 11      0       Aloft Montevideo Hotel                                -34.924754
# 12      True    0                                                       0.000000
# 13      0       Tapis Rouge VIP Boutique Batumi                        41.651400
# 14      0       Refugi Cap del Rec                                     42.431239
# 15      0       Extended Stay America Philadelphia Mt Laurel - ...     39.917190
# 16      0       Nut Grove Manor                                       -25.320067
# 17      0       The Station Room                                       38.344139
#
#                                                                                     \
# solution                                                           better_solution
# level_1 missing name
# 0       True    0                                                         0.000000
# 1       0       The Quilon Beach Hotel and Convention Center              8.875560
# 2       True    0                                                         0.000000
# 3       0       Hotel Rey David                                          16.789122
# 4       0       Elsje's Country Inn                                     -26.088950
# 5       0       21 Palms                                                 19.295280
# 6       0       Hostel Mendoza Suites                                   -32.885292
# 7       0       Royal Chalet Guest House                                 31.473880
# 8       0       Travelodge by Wyndham New Orleans West Harvey H...       29.899901
# 9       0       Grand Hotel Açores Atlântico                             37.740209
# 10      0       Gino Feruci Braga                                        -6.917909
# 11      0       Aloft Montevideo Hotel                                  -34.924754
# 12      True    0                                                         0.000000
# 13      0       Tapis Rouge VIP Boutique Batumi                          41.651400
# 14      0       Refugi Cap del Rec                                       42.431239
# 15      0       Extended Stay America Philadelphia Mt Laurel - ...       39.917190
# 16      0       Nut Grove Manor                                         -25.320067
# 17      0       The Station Room                                         38.344139
#
#                                                                              lon  \
# solution                                                           base_solution
# level_1 missing name
# 0       True    0                                                       0.000000
# 1       0       The Quilon Beach Hotel and Convention Center           76.592505
# 2       True    0                                                       0.000000
# 3       0       Hotel Rey David                                       -96.670486
# 4       0       Elsje's Country Inn                                    28.305160
# 5       0       21 Palms                                              -69.180976
# 6       0       Hostel Mendoza Suites                                 -68.842049
# 7       0       Royal Chalet Guest House                               74.275900
# 8       0       Travelodge by Wyndham New Orleans West Harvey H...    -90.072369
# 9       0       Grand Hotel Açores Atlântico                          -25.661778
# 10      0       Gino Feruci Braga                                     107.609439
# 11      0       Aloft Montevideo Hotel                                -56.157977
# 12      True    0                                                       0.000000
# 13      0       Tapis Rouge VIP Boutique Batumi                        41.633537
# 14      0       Refugi Cap del Rec                                      1.668360
# 15      0       Extended Stay America Philadelphia Mt Laurel - ...    -74.947700
# 16      0       Nut Grove Manor                                        31.043023
# 17      0       The Station Room                                       -0.494307
#
#                                                                                     \
# solution                                                           better_solution
# level_1 missing name
# 0       True    0                                                         0.000000
# 1       0       The Quilon Beach Hotel and Convention Center             76.592505
# 2       True    0                                                         0.000000
# 3       0       Hotel Rey David                                         -96.670486
# 4       0       Elsje's Country Inn                                      28.305160
# 5       0       21 Palms                                                -69.180976
# 6       0       Hostel Mendoza Suites                                   -68.842049
# 7       0       Royal Chalet Guest House                                 74.275900
# 8       0       Travelodge by Wyndham New Orleans West Harvey H...      -90.072369
# 9       0       Grand Hotel Açores Atlântico                            -25.661778
# 10      0       Gino Feruci Braga                                       107.609439
# 11      0       Aloft Montevideo Hotel                                  -56.157977
# 12      True    0                                                         0.000000
# 13      0       Tapis Rouge VIP Boutique Batumi                          41.633537
# 14      0       Refugi Cap del Rec                                        1.668360
# 15      0       Extended Stay America Philadelphia Mt Laurel - ...      -74.947700
# 16      0       Nut Grove Manor                                          31.043023
# 17      0       The Station Room                                         -0.494307
#
#                                                                            price  \
# solution                                                           base_solution
# level_1 missing name
# 0       True    0                                                            0.0
# 1       0       The Quilon Beach Hotel and Convention Center                51.0
# 2       True    0                                                            0.0
# 3       0       Hotel Rey David                                             16.0
# 4       0       Elsje's Country Inn                                         58.0
# 5       0       21 Palms                                                    65.0
# 6       0       Hostel Mendoza Suites                                       22.0
# 7       0       Royal Chalet Guest House                                    98.0
# 8       0       Travelodge by Wyndham New Orleans West Harvey H...          70.0
# 9       0       Grand Hotel Açores Atlântico                                86.0
# 10      0       Gino Feruci Braga                                           32.0
# 11      0       Aloft Montevideo Hotel                                      84.0
# 12      True    0                                                            0.0
# 13      0       Tapis Rouge VIP Boutique Batumi                             59.0
# 14      0       Refugi Cap del Rec                                          65.0
# 15      0       Extended Stay America Philadelphia Mt Laurel - ...          92.0
# 16      0       Nut Grove Manor                                            135.0
# 17      0       The Station Room                                           115.0
#
#                                                                                     \
# solution                                                           better_solution
# level_1 missing name
# 0       True    0                                                              0.0
# 1       0       The Quilon Beach Hotel and Convention Center                   0.0
# 2       True    0                                                              0.0
# 3       0       Hotel Rey David                                                0.0
# 4       0       Elsje's Country Inn                                            0.0
# 5       0       21 Palms                                                       0.0
# 6       0       Hostel Mendoza Suites                                          0.0
# 7       0       Royal Chalet Guest House                                       0.0
# 8       0       Travelodge by Wyndham New Orleans West Harvey H...             0.0
# 9       0       Grand Hotel Açores Atlântico                                   0.0
# 10      0       Gino Feruci Braga                                              0.0
# 11      0       Aloft Montevideo Hotel                                         0.0
# 12      True    0                                                              0.0
# 13      0       Tapis Rouge VIP Boutique Batumi                                0.0
# 14      0       Refugi Cap del Rec                                             0.0
# 15      0       Extended Stay America Philadelphia Mt Laurel - ...             0.0
# 16      0       Nut Grove Manor                                                0.0
# 17      0       The Station Room                                               0.0
#
#                                                                            stars  \
# solution                                                           base_solution
# level_1 missing name
# 0       True    0                                                            0.0
# 1       0       The Quilon Beach Hotel and Convention Center                 5.0
# 2       True    0                                                            0.0
# 3       0       Hotel Rey David                                              2.5
# 4       0       Elsje's Country Inn                                          2.0
# 5       0       21 Palms                                                     3.0
# 6       0       Hostel Mendoza Suites                                        1.5
# 7       0       Royal Chalet Guest House                                     2.0
# 8       0       Travelodge by Wyndham New Orleans West Harvey H...           1.5
# 9       0       Grand Hotel Açores Atlântico                                 5.0
# 10      0       Gino Feruci Braga                                            4.0
# 11      0       Aloft Montevideo Hotel                                       3.5
# 12      True    0                                                            0.0
# 13      0       Tapis Rouge VIP Boutique Batumi                              4.5
# 14      0       Refugi Cap del Rec                                           1.5
# 15      0       Extended Stay America Philadelphia Mt Laurel - ...           2.5
# 16      0       Nut Grove Manor                                              5.0
# 17      0       The Station Room                                             2.5
#
#
# solution                                                           better_solution
# level_1 missing name
# 0       True    0                                                              0.0
# 1       0       The Quilon Beach Hotel and Convention Center                   5.0
# 2       True    0                                                              0.0
# 3       0       Hotel Rey David                                                2.5
# 4       0       Elsje's Country Inn                                            2.0
# 5       0       21 Palms                                                       3.0
# 6       0       Hostel Mendoza Suites                                          1.5
# 7       0       Royal Chalet Guest House                                       2.0
# 8       0       Travelodge by Wyndham New Orleans West Harvey H...             1.5
# 9       0       Grand Hotel Açores Atlântico                                   5.0
# 10      0       Gino Feruci Braga                                              4.0
# 11      0       Aloft Montevideo Hotel                                         3.5
# 12      True    0                                                              0.0
# 13      0       Tapis Rouge VIP Boutique Batumi                                4.5
# 14      0       Refugi Cap del Rec                                             1.5
# 15      0       Extended Stay America Philadelphia Mt Laurel - ...             2.5
# 16      0       Nut Grove Manor                                                5.0
# 17      0       The Station Room                                               2.5
